# %%
# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %%
# create the DataFrame
df = pd.read_csv("data/seven_up_and_down.csv")
df.index.name = "Round"
df
# Out:
#        Brennan  Mom  Katelyn  Dad  Ethan  Collin
# Round
# 0            0    0        0    0      0       0
# 1           30   20       25   -5     -5      25
# 2           -5   25       30   20     -5      25
# 3           -5   -5       25   -5     -5      30
# 4           25   25       25   -5     -5      25
# 5           -5   -5       20   25     20      20
# 6           20   20       -5   20     20      20
# 7           20   20       20   20     20      -5
# 8           -5   25       -5   20     25      20
# 9           -5   25       20   20     -5      25
# 10         -10   -5       -5   20     20      30
# 11          -5   25       20   -5     30      -5
# 12         -10   -5       25   35     25      20
# 13         -15   30       30   -5     30      -5

# %%
# %%
# get total score per round, and plot
cs = df.cumsum()
cs.plot()
cs
# Out:
#        Brennan  Mom  Katelyn  Dad  Ethan  Collin
# Round
# 0            0    0        0    0      0       0
# 1           30   20       25   -5     -5      25
# 2           25   45       55   15    -10      50
# 3           20   40       80   10    -15      80
# 4           45   65      105    5    -20     105
# 5           40   60      125   30      0     125
# 6           60   80      120   50     20     145
# 7           80  100      140   70     40     140
# 8           75  125      135   90     65     160
# 9           70  150      155  110     60     185
# 10          60  145      150  130     80     215
# 11          55  170      170  125    110     210
# 12          45  165      195  160    135     230
# 13          30  195      225  155    165     225

# %%
# %%
# generate stats per person
player_stats = pd.DataFrame({
    "Total_Score": df.sum(),
    "Average_Gain": df.mean(),
    "Biggest_Gain": df.max(),
    "Biggest_Drop": df.min(),
    "Highest_Score": cs.max(),
    "Lowest_Score": cs.min(),
    "Times_Increased": (df > 0).sum(),
    "Times_Decreased": (df < 0).sum()
})
player_stats
# Out:
#          Total_Score  Average_Gain  Biggest_Gain  Biggest_Drop  Highest_Score  \
# Brennan           30      2.142857            30           -15             80
# Mom              195     13.928571            30            -5            195
# Katelyn          225     16.071429            30            -5            225
# Dad              155     11.071429            35            -5            160
# Ethan            165     11.785714            30            -5            165
# Collin           225     16.071429            30            -5            230
#
#          Lowest_Score  Times_Increased  Times_Decreased
# Brennan             0                4                9
# Mom                 0                9                4
# Katelyn             0               10                3
# Dad                -5                8                5
# Ethan             -20                8                5
# Collin              0               10                3

# %%
# %%
# generate stats about the game
# [TODO) Add more game stats
game_stats = pd.Series({
    "Winner": player_stats["Total_Score"].idxmax(),
    "Looser": player_stats["Total_Score"].idxmin(),
})
game_stats
# Out:
# Winner    Katelyn
# Looser    Brennan
# dtype: object
