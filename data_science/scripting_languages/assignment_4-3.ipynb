# %% [markdown]
# # Random Number Generation

# %%
import pandas as pd
import numpy as np
import numpy.random as r
import matplotlib.pyplot as plt

# %%
rands = r.randint(low=0, high=15, size=(100, 1))

df = pd.DataFrame(rands)

fig, ax = plt.subplots()
df.plot.hist(ax=ax)
# Out:
# <Axes: ylabel='Frequency'>
